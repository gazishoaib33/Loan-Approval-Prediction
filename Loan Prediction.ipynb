# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("Loan Prediction Dataset.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount Property_Area Loan_Status
# 0             5849                0.0         NaN         Urban           Y
# 1             4583             1508.0       128.0         Rural           N
# 2             3000                0.0        66.0         Urban           Y
# 3             2583             2358.0       120.0         Urban           Y
# 4             6000                0.0       141.0         Urban           Y

# %%
df.describe()
# Out:
#        Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount
# count  913.000000       938.000000         938.000000  911.000000
# mean     0.783133      5211.906183        1598.122516  143.162459
# std      1.030808      5804.927551        2730.089846   78.318496
# min      0.000000         0.000000           0.000000    9.000000
# 25%      0.000000      2875.250000           0.000000  100.000000
# 50%      0.000000      3793.000000        1094.500000  127.000000
# 75%      2.000000      5531.500000        2366.500000  162.000000
# max      3.000000     81000.000000       41667.000000  700.000000

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents           float64
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Loan_ID              324
# Gender                24
# Married                3
# Dependents            25
# Education              0
# Self_Employed         54
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            27
# Property_Area          0
# Loan_Status            0
# dtype: int64

# %%
df.shape
# Out:
# (938, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 938 entries, 0 to 937
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             914 non-null    object
#  2   Married            935 non-null    object
#  3   Dependents         913 non-null    float64
#  4   Education          938 non-null    object
#  5   Self_Employed      884 non-null    object
#  6   ApplicantIncome    938 non-null    int64
#  7   CoapplicantIncome  938 non-null    float64
#  8   LoanAmount         911 non-null    float64
#  9   Property_Area      938 non-null    object
#  10  Loan_Status        938 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 80.7+ KB

# %%
df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No         0.0      Graduate            No
# 1    LP001003    Male     Yes         1.0      Graduate            No
# 2    LP001005    Male     Yes         0.0      Graduate           Yes
# 3    LP001006    Male     Yes         0.0  Not Graduate            No
# 4    LP001008    Male      No         0.0      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 933       NaN    Male      No         0.0      Graduate            No
# 934       NaN    Male     Yes         1.0      Graduate            No
# 935       NaN  Female     Yes         0.0  Not Graduate            No
# 936       NaN    Male     Yes         3.0      Graduate            No
# 937       NaN    Male      No         1.0      Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount Property_Area Loan_Status
# 0               5849                0.0         NaN         Urban           Y
# 1               4583             1508.0       128.0         Rural           N
# 2               3000                0.0        66.0         Urban           Y
# 3               2583             2358.0       120.0         Urban           Y
# 4               6000                0.0       141.0         Urban           Y
# ..               ...                ...         ...           ...         ...
# 933             3083             2738.0       120.0         Urban           N
# 934             2667             1542.0       148.0         Rural           Y
# 935             1647             1762.0       181.0         Urban           Y
# 936             3400                0.0        80.0         Urban           N
# 937            16000             5000.0        40.0     Semiurban           Y
#
# [938 rows x 11 columns]

# %%
#fill the missing values for numerical terms - mean
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())

# %%
#fill the missing values for categorical terms - mode
df['Gender'] = df["Gender"].fillna(df['Gender'].mode()[0])
df['Married'] = df["Married"].fillna(df['Married'].mode()[0])
df['Dependents'] = df["Dependents"].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df["Self_Employed"].fillna(df['Self_Employed'].mode()[0])

# %%
df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No         0.0      Graduate            No
# 1    LP001003    Male     Yes         1.0      Graduate            No
# 2    LP001005    Male     Yes         0.0      Graduate           Yes
# 3    LP001006    Male     Yes         0.0  Not Graduate            No
# 4    LP001008    Male      No         0.0      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 933       NaN    Male      No         0.0      Graduate            No
# 934       NaN    Male     Yes         1.0      Graduate            No
# 935       NaN  Female     Yes         0.0  Not Graduate            No
# 936       NaN    Male     Yes         3.0      Graduate            No
# 937       NaN    Male      No         1.0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount Property_Area Loan_Status
# 0               5849                0.0  143.162459         Urban           Y
# 1               4583             1508.0  128.000000         Rural           N
# 2               3000                0.0   66.000000         Urban           Y
# 3               2583             2358.0  120.000000         Urban           Y
# 4               6000                0.0  141.000000         Urban           Y
# ..               ...                ...         ...           ...         ...
# 933             3083             2738.0  120.000000         Urban           N
# 934             2667             1542.0  148.000000         Rural           Y
# 935             1647             1762.0  181.000000         Urban           Y
# 936             3400                0.0   80.000000         Urban           N
# 937            16000             5000.0   40.000000     Semiurban           Y
#
# [938 rows x 11 columns]

# %%
df= df.drop(columns =['Loan_ID'],axis=1)

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(12,15))
plt.show()

# %%
sns.countplot(df['Gender'])
df['Gender'].value_counts()
# Out:
# E:\11th semester\CSE445 (ITN)\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Male      761
# Female    177
# Name: Gender, dtype: int64

# %%
sns.countplot(df['Married'])
df['Married'].value_counts()
# Out:
# E:\11th semester\CSE445 (ITN)\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Yes    603
# No     335
# Name: Married, dtype: int64

# %%
sns.countplot(df['Dependents'])
df['Dependents'].value_counts()
# Out:
# E:\11th semester\CSE445 (ITN)\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0.0    546
# 2.0    155
# 1.0    153
# 3.0     84
# Name: Dependents, dtype: int64

# %%
sns.countplot(df['Education'])
df['Education'].value_counts()
# Out:
# E:\11th semester\CSE445 (ITN)\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Graduate        729
# Not Graduate    209
# Name: Education, dtype: int64

# %%
sns.countplot(df['Self_Employed'])
df['Self_Employed'].value_counts()
# Out:
# E:\11th semester\CSE445 (ITN)\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No     826
# Yes    112
# Name: Self_Employed, dtype: int64

# %%
sns.countplot(df['Loan_Status'])
df['Loan_Status'].value_counts()
# Out:
# E:\11th semester\CSE445 (ITN)\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Y    607
# N    331
# Name: Loan_Status, dtype: int64

# %%
df.plot(kind="scatter", x="ApplicantIncome", y="LoanAmount", alpha=0.8)
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
sns.barplot(x='Dependents', y='ApplicantIncome', data = df)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Gender','Married','Education','Self_Employed','Property_Area','Loan_Status','Dependents']
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          0              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          1              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 933       1        0           0          0              0             3083
# 934       1        1           1          0              0             2667
# 935       0        1           0          1              0             1647
# 936       1        1           3          0              0             3400
# 937       1        0           1          0              0            16000
#
#      CoapplicantIncome  LoanAmount  Property_Area  Loan_Status
# 0                  0.0  143.162459              2            1
# 1               1508.0  128.000000              0            0
# 2                  0.0   66.000000              2            1
# 3               2358.0  120.000000              2            1
# 4                  0.0  141.000000              2            1
# ..                 ...         ...            ...          ...
# 933             2738.0  120.000000              2            0
# 934             1542.0  148.000000              0            1
# 935             1762.0  181.000000              2            1
# 936                0.0   80.000000              2            0
# 937             5000.0   40.000000              1            1
#
# [938 rows x 10 columns]

# %%
#sns.barplot(x="Gender", y="Married", data=df)

# %%
# df.replace({'Gender': {'Female':0, 'Male':1 }, 
#           'Married': {'No':0, 'Yes':1},
#           'Education': {'Not Graduate':0, 'Graduate':1},
#           'Self_Employed': {'No':0, 'Yes':1},
#           'Loan_Status': {'N':0, 'Y':1},
#           'Dependents': {'3+':3}},inplace= True)
# df

# %%
sns.catplot(data=df, x="Gender", y="Loan_Status", hue="Gender")

# %%
corr = df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot = True, cmap="BuPu")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Stratified Sampling

# %%
#specify input and output attributes
x = df.drop(columns =['Loan_Status'],axis=1)
y = df['Loan_Status']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
print(y_train.value_counts(normalize=True), '\n\n')

print(y_test.value_counts(normalize=True))
# Out:
# 1    0.658606
# 0    0.341394
# Name: Loan_Status, dtype: float64
#
#
# 1    0.612766
# 0    0.387234
# Name: Loan_Status, dtype: float64

# %%
sns.pairplot(df)

# %%
sns.barplot(x = 'Married',y = 'LoanAmount',data = df)
 
plt.show()

# %%
sns.barplot(x = 'Gender',
            y = 'ApplicantIncome',
            data = df,
            palette = "Blues")
 
plt.show()

# %%
df.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
# def classify(model, x ,y):
#     x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)
#     model.fit(x_train,y_train)
#     print("Accuracy is", model.score(x_test,y_test)*100)
#     score = cross_val_score(model, x, y, cv=5)
#     print("Cross validation is,",np.mean(score)*100)

# %%
# raw_data = pd.read_csv('Loan Prediction Dataset.csv')

# x = raw_data[[ 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Property_Area']]

# y = raw_data['Loan_Status']

# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# model = LinearRegression()

# model.fit(x_train, y_train)

# print(model.coef_)

# print(model.intercept_)

# pd.DataFrame(model.coef_, x.columns, columns = ['Coeff'])

# predictions = model.predict(x_test)

# # plt.scatter(y_test, predictions)

# plt.hist(y_test - predictions)

# metrics.mean_absolute_error(y_test, predictions)

# metrics.mean_squared_error(y_test, predictions)

# np.sqrt(metrics.mean_squared_error(y_test, predictions))

# %%
# from sklearn import preprocessing
# x_array = np.array(df['LoanAmount'])
# normalized_arr = preprocessing.normalize([x_array])
# print(normalized_arr)

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler= MinMaxScaler()
df= scaler.fit_transform(df)

# %%
df= pd.DataFrame(df, columns= ['Gender','Married','Dependents',
                               'Self_Employed','ApplicantIncome',
                               'CoapplicantIncome',
                               'Education','Property_Area',
                               'Loan_Status','LoanAmount' ])

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#            Gender     Married  Dependents  Self_Employed  ApplicantIncome  \
# count  938.000000  938.000000  938.000000     938.000000       938.000000
# mean     0.811301    0.642857    0.254087       0.222814         0.119403
# std      0.391478    0.479413    0.341588       0.416357         0.324435
# min      0.000000    0.000000    0.000000       0.000000         0.000000
# 25%      1.000000    0.000000    0.000000       0.000000         0.000000
# 50%      1.000000    1.000000    0.000000       0.000000         0.000000
# 75%      1.000000    1.000000    0.666667       0.000000         0.000000
# max      1.000000    1.000000    1.000000       1.000000         1.000000
#
#        CoapplicantIncome   Education  Property_Area  Loan_Status  LoanAmount
# count         938.000000  938.000000     938.000000   938.000000  938.000000
# mean            0.064345    0.038355       0.194157     0.527186    0.647122
# std             0.071666    0.065522       0.111696     0.398847    0.478120
# min             0.000000    0.000000       0.000000     0.000000    0.000000
# 25%             0.035497    0.000000       0.134588     0.000000    0.000000
# 50%             0.046827    0.026268       0.172214     0.500000    1.000000
# 75%             0.068290    0.056796       0.219609     1.000000    1.000000
# max             1.000000    1.000000       1.000000     1.000000    1.000000

# %%
df.plot(kind="scatter", x="ApplicantIncome", y="LoanAmount", alpha=0.8)
# Out:
# <AxesSubplot:xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %% [markdown]
# ## Standarization

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
df= scaler.fit_transform(df)

# %%
df= pd.DataFrame(df, columns= ['Gender','Married','Dependents',
                               'Self_Employed','ApplicantIncome',
                               'CoapplicantIncome',
                               'Education','Property_Area',
                               'Loan_Status','LoanAmount' ])

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#              Gender       Married    Dependents  Self_Employed  \
# count  9.380000e+02  9.380000e+02  9.380000e+02   9.380000e+02
# mean   2.974403e-16 -9.942296e-18 -1.424471e-16  -1.673620e-16
# std    1.000533e+00  1.000533e+00  1.000533e+00   1.000533e+00
# min   -2.073508e+00 -1.341641e+00 -7.442359e-01  -5.354382e-01
# 25%    4.822745e-01 -1.341641e+00 -7.442359e-01  -5.354382e-01
# 50%    4.822745e-01  7.453560e-01 -7.442359e-01  -5.354382e-01
# 75%    4.822745e-01  7.453560e-01  1.208473e+00  -5.354382e-01
# max    4.822745e-01  7.453560e-01  2.184827e+00   1.867629e+00
#
#        ApplicantIncome  CoapplicantIncome     Education  Property_Area  \
# count     9.380000e+02       9.380000e+02  9.380000e+02   9.380000e+02
# mean     -2.479656e-16      -5.941705e-17  5.255213e-17  -1.093653e-16
# std       1.000533e+00       1.000533e+00  1.000533e+00   1.000533e+00
# min      -3.682298e-01      -8.983207e-01 -5.856859e-01  -1.739191e+00
# 25%      -3.682298e-01      -4.027445e-01 -5.856859e-01  -5.336023e-01
# 50%      -3.682298e-01      -2.445617e-01 -1.845695e-01  -1.965559e-01
# 75%      -3.682298e-01       5.508498e-02  2.815978e-01   2.279930e-01
# max       2.715695e+00       1.306279e+01  1.468459e+01   7.218466e+00
#
#         Loan_Status    LoanAmount
# count  9.380000e+02  9.380000e+02
# mean   5.715341e-17 -3.155495e-16
# std    1.000533e+00  1.000533e+00
# min   -1.322480e+00 -1.354192e+00
# 25%   -1.322480e+00 -1.354192e+00
# 50%   -6.819663e-02  7.384475e-01
# 75%    1.186086e+00  7.384475e-01
# max    1.186086e+00  7.384475e-01
